# %% [markdown]
# <a href="https://colab.research.google.com/github/KileyMeringer/COVID19_Tweets_Dataset/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/lopezbec/COVID19_Tweets_Dataset/refs/heads/main/Summary_Details/2022_01/2022_01_01_00_Summary_Details.csv"

try:
    df = pd.read_csv(url)
    print("CSV file loaded successfully!")
    print(df.head())  # Display the first few rows

except Exception as e:
    print(f"Error loading CSV file: {e}")
# Out:
# CSV file loaded successfully!
#               Tweet_ID Language Geolocation_coordinate   RT  Likes  Retweets  \
# 0  1477068982054268936       en                     NO   NO      0         0
# 1  1477070543174225927       en                     NO   NO      1         0
# 2  1477070851006779393       en                     NO   NO      0         0
# 3  1477067130210295809       fr                     NO  YES      0         3
# 4  1477067209017110533       fr                     NO  YES      0         3
#
#   Country                    Date Created
# 0     NaN  Sat Jan 01 00:07:42 +0000 2022
# 1     NaN  Sat Jan 01 00:13:54 +0000 2022
# 2     NaN  Sat Jan 01 00:15:08 +0000 2022
# 3     NaN  Sat Jan 01 00:00:21 +0000 2022
# 4     NaN  Sat Jan 01 00:00:39 +0000 2022
